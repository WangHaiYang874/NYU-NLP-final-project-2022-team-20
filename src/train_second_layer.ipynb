# %%
import numpy as np
import pandas as pd
import re
import string
import pickle
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import stopwords
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn import preprocessing
import warnings

from torch.utils.data import TensorDataset, DataLoader
import torch
from torch import nn
from torchvision import datasets
from torchvision.transforms import ToTensor, Lambda, Compose
import matplotlib.pyplot as plt
import datetime
import os

warnings.filterwarnings("ignore")

# %% [markdown]
# ## read in all the pretrained models

# %%
# loading pretrained models

feature_extractor_path = '../models/features2021-12-11.model'

with open(feature_extractor_path,'rb') as f:
    feature_extractor = pickle.load(f)

# %%
first_layer_model_path = '../models/first_layer/'
first_layer_model_version = '2021-12-13'
# ❗

first_layer_model = dict()
for modelname in os.listdir(first_layer_model_path):
    if first_layer_model_version in modelname:
        with open(first_layer_model_path + modelname,'rb') as f:
            first_layer_model[modelname[:4]] = pickle.load(f)

# %%
df = pd.read_csv('../data/mbti_1.csv', index_col=0)

# %%
train_X = feature_extractor.get_features(df.body)

# %%
def flatten_one_row(feature):
    tfidf, emoticon, topic = feature
    tfidf = np.array(tfidf.todense()).flatten()
    return np.concatenate([tfidf, emoticon, topic], axis=None)

train_X = np.array([flatten_one_row(row) for row in train_X])

# %%
help(first_layer_model['I___'])
# Out:
# Help on RandomForestClassifier in module sklearn.ensemble._forest object:
#
# class RandomForestClassifier(ForestClassifier)
#  |  RandomForestClassifier(n_estimators=100, *, criterion='gini', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features='auto', max_leaf_nodes=None, min_impurity_decrease=0.0, bootstrap=True, oob_score=False, n_jobs=None, random_state=None, verbose=0, warm_start=False, class_weight=None, ccp_alpha=0.0, max_samples=None)
#  |
#  |  A random forest classifier.
#  |
#  |  A random forest is a meta estimator that fits a number of decision tree
#  |  classifiers on various sub-samples of the dataset and uses averaging to
#  |  improve the predictive accuracy and control over-fitting.
#  |  The sub-sample size is controlled with the `max_samples` parameter if
#  |  `bootstrap=True` (default), otherwise the whole dataset is used to build
#  |  each tree.
#  |
#  |  Read more in the :ref:`User Guide <forest>`.
#  |
#  |  Parameters
#  |  ----------
#  |  n_estimators : int, default=100
#  |      The number of trees in the forest.
#  |
#  |      .. versionchanged:: 0.22
#  |         The default value of ``n_estimators`` changed from 10 to 100
#  |         in 0.22.
#  |
#  |  criterion : {"gini", "entropy"}, default="gini"
#  |      The function to measure the quality of a split. Supported criteria are
#  |      "gini" for the Gini impurity and "entropy" for the information gain.
#  |      Note: this parameter is tree-specific.
#  |
#  |  max_depth : int, default=None
#  |      The maximum depth of the tree. If None, then nodes are expanded until
#  |      all leaves are pure or until all leaves contain less than
#  |      min_samples_split samples.
#  |
#  |  min_samples_split : int or float, default=2
#  |      The minimum number of samples required to split an internal node:
#  |
#  |      - If int, then consider `min_samples_split` as the minimum number.
#  |      - If float, then `min_samples_split` is a fraction and
#  |        `ceil(min_samples_split * n_samples)` are the minimum
#  |        number of samples for each split.
#  |
#  |      .. versionchanged:: 0.18
#  |         Added float values for fractions.
#  |
#  |  min_samples_leaf : int or float, default=1
#  |      The minimum number of samples required to be at a leaf node.
#  |      A split point at any depth will only be considered if it leaves at
#  |      least ``min_samples_leaf`` training samples in each of the left and
#  |      right branches.  This may have the effect of smoothing the model,
#  |      especially in regression.
#  |
#  |      - If int, then consider `min_samples_leaf` as the minimum number.
#  |      - If float, then `min_samples_leaf` is a fraction and
#  |        `ceil(min_samples_leaf * n_samples)` are the minimum
#  |        number of samples for each node.
#  |
#  |      .. versionchanged:: 0.18
#  |         Added float values for fractions.
#  |
#  |  min_weight_fraction_leaf : float, default=0.0
#  |      The minimum weighted fraction of the sum total of weights (of all
#  |      the input samples) required to be at a leaf node. Samples have
#  |      equal weight when sample_weight is not provided.
#  |
#  |  max_features : {"auto", "sqrt", "log2"}, int or float, default="auto"
#  |      The number of features to consider when looking for the best split:
#  |
#  |      - If int, then consider `max_features` features at each split.
#  |      - If float, then `max_features` is a fraction and
#  |        `round(max_features * n_features)` features are considered at each
#  |        split.
#  |      - If "auto", then `max_features=sqrt(n_features)`.
#  |      - If "sqrt", then `max_features=sqrt(n_features)` (same as "auto").
#  |      - If "log2", then `max_features=log2(n_features)`.
#  |      - If None, then `max_features=n_features`.
#  |
#  |      Note: the search for a split does not stop until at least one
#  |      valid partition of the node samples is found, even if it requires to
#  |      effectively inspect more than ``max_features`` features.
#  |
#  |  max_leaf_nodes : int, default=None
#  |      Grow trees with ``max_leaf_nodes`` in best-first fashion.
#  |      Best nodes are defined as relative reduction in impurity.
#  |      If None then unlimited number of leaf nodes.
#  |
#  |  min_impurity_decrease : float, default=0.0
#  |      A node will be split if this split induces a decrease of the impurity
#  |      greater than or equal to this value.
#  |
#  |      The weighted impurity decrease equation is the following::
#  |
#  |          N_t / N * (impurity - N_t_R / N_t * right_impurity
#  |                              - N_t_L / N_t * left_impurity)
#  |
#  |      where ``N`` is the total number of samples, ``N_t`` is the number of
#  |      samples at the current node, ``N_t_L`` is the number of samples in the
#  |      left child, and ``N_t_R`` is the number of samples in the right child.
#  |
#  |      ``N``, ``N_t``, ``N_t_R`` and ``N_t_L`` all refer to the weighted sum,
#  |      if ``sample_weight`` is passed.
#  |
#  |      .. versionadded:: 0.19
#  |
#  |  bootstrap : bool, default=True
#  |      Whether bootstrap samples are used when building trees. If False, the
#  |      whole dataset is used to build each tree.
#  |
#  |  oob_score : bool, default=False
#  |      Whether to use out-of-bag samples to estimate the generalization score.
#  |      Only available if bootstrap=True.
#  |
#  |  n_jobs : int, default=None
#  |      The number of jobs to run in parallel. :meth:`fit`, :meth:`predict`,
#  |      :meth:`decision_path` and :meth:`apply` are all parallelized over the
#  |      trees. ``None`` means 1 unless in a :obj:`joblib.parallel_backend`
#  |      context. ``-1`` means using all processors. See :term:`Glossary
#  |      <n_jobs>` for more details.
#  |
#  |  random_state : int, RandomState instance or None, default=None
#  |      Controls both the randomness of the bootstrapping of the samples used
#  |      when building trees (if ``bootstrap=True``) and the sampling of the
#  |      features to consider when looking for the best split at each node
#  |      (if ``max_features < n_features``).
#  |      See :term:`Glossary <random_state>` for details.
#  |
#  |  verbose : int, default=0
#  |      Controls the verbosity when fitting and predicting.
#  |
#  |  warm_start : bool, default=False
#  |      When set to ``True``, reuse the solution of the previous call to fit
#  |      and add more estimators to the ensemble, otherwise, just fit a whole
#  |      new forest. See :term:`the Glossary <warm_start>`.
#  |
#  |  class_weight : {"balanced", "balanced_subsample"}, dict or list of dicts,             default=None
#  |      Weights associated with classes in the form ``{class_label: weight}``.
#  |      If not given, all classes are supposed to have weight one. For
#  |      multi-output problems, a list of dicts can be provided in the same
#  |      order as the columns of y.
#  |
#  |      Note that for multioutput (including multilabel) weights should be
#  |      defined for each class of every column in its own dict. For example,
#  |      for four-class multilabel classification weights should be
#  |      [{0: 1, 1: 1}, {0: 1, 1: 5}, {0: 1, 1: 1}, {0: 1, 1: 1}] instead of
#  |      [{1:1}, {2:5}, {3:1}, {4:1}].
#  |
#  |      The "balanced" mode uses the values of y to automatically adjust
#  |      weights inversely proportional to class frequencies in the input data
#  |      as ``n_samples / (n_classes * np.bincount(y))``
#  |
#  |      The "balanced_subsample" mode is the same as "balanced" except that
#  |      weights are computed based on the bootstrap sample for every tree
#  |      grown.
#  |
#  |      For multi-output, the weights of each column of y will be multiplied.
#  |
#  |      Note that these weights will be multiplied with sample_weight (passed
#  |      through the fit method) if sample_weight is specified.
#  |
#  |  ccp_alpha : non-negative float, default=0.0
#  |      Complexity parameter used for Minimal Cost-Complexity Pruning. The
#  |      subtree with the largest cost complexity that is smaller than
#  |      ``ccp_alpha`` will be chosen. By default, no pruning is performed. See
#  |      :ref:`minimal_cost_complexity_pruning` for details.
#  |
#  |      .. versionadded:: 0.22
#  |
#  |  max_samples : int or float, default=None
#  |      If bootstrap is True, the number of samples to draw from X
#  |      to train each base estimator.
#  |
#  |      - If None (default), then draw `X.shape[0]` samples.
#  |      - If int, then draw `max_samples` samples.
#  |      - If float, then draw `max_samples * X.shape[0]` samples. Thus,
#  |        `max_samples` should be in the interval `(0.0, 1.0]`.
#  |
#  |      .. versionadded:: 0.22
#  |
#  |  Attributes
#  |  ----------
#  |  base_estimator_ : DecisionTreeClassifier
#  |      The child estimator template used to create the collection of fitted
#  |      sub-estimators.
#  |
#  |  estimators_ : list of DecisionTreeClassifier
#  |      The collection of fitted sub-estimators.
#  |
#  |  classes_ : ndarray of shape (n_classes,) or a list of such arrays
#  |      The classes labels (single output problem), or a list of arrays of
#  |      class labels (multi-output problem).
#  |
#  |  n_classes_ : int or list
#  |      The number of classes (single output problem), or a list containing the
#  |      number of classes for each output (multi-output problem).
#  |
#  |  n_features_ : int
#  |      The number of features when ``fit`` is performed.
#  |
#  |      .. deprecated:: 1.0
#  |          Attribute `n_features_` was deprecated in version 1.0 and will be
#  |          removed in 1.2. Use `n_features_in_` instead.
#  |
#  |  n_features_in_ : int
#  |      Number of features seen during :term:`fit`.
#  |
#  |      .. versionadded:: 0.24
#  |
#  |  feature_names_in_ : ndarray of shape (`n_features_in_`,)
#  |      Names of features seen during :term:`fit`. Defined only when `X`
#  |      has feature names that are all strings.
#  |      .. versionadded:: 1.0
#  |
#  |  n_outputs_ : int
#  |      The number of outputs when ``fit`` is performed.
#  |
#  |  feature_importances_ : ndarray of shape (n_features,)
#  |      The impurity-based feature importances.
#  |      The higher, the more important the feature.
#  |      The importance of a feature is computed as the (normalized)
#  |      total reduction of the criterion brought by that feature.  It is also
#  |      known as the Gini importance.
#  |
#  |      Warning: impurity-based feature importances can be misleading for
#  |      high cardinality features (many unique values). See
#  |      :func:`sklearn.inspection.permutation_importance` as an alternative.
#  |
#  |  oob_score_ : float
#  |      Score of the training dataset obtained using an out-of-bag estimate.
#  |      This attribute exists only when ``oob_score`` is True.
#  |
#  |  oob_decision_function_ : ndarray of shape (n_samples, n_classes) or             (n_samples, n_classes, n_outputs)
#  |      Decision function computed with out-of-bag estimate on the training
#  |      set. If n_estimators is small it might be possible that a data point
#  |      was never left out during the bootstrap. In this case,
#  |      `oob_decision_function_` might contain NaN. This attribute exists
#  |      only when ``oob_score`` is True.
#  |
#  |  See Also
#  |  --------
#  |  sklearn.tree.DecisionTreeClassifier : A decision tree classifier.
#  |  sklearn.ensemble.ExtraTreesClassifier : Ensemble of extremely randomized
#  |      tree classifiers.
#  |
#  |  Notes
#  |  -----
#  |  The default values for the parameters controlling the size of the trees
#  |  (e.g. ``max_depth``, ``min_samples_leaf``, etc.) lead to fully grown and
#  |  unpruned trees which can potentially be very large on some data sets. To
#  |  reduce memory consumption, the complexity and size of the trees should be
#  |  controlled by setting those parameter values.
#  |
#  |  The features are always randomly permuted at each split. Therefore,
#  |  the best found split may vary, even with the same training data,
#  |  ``max_features=n_features`` and ``bootstrap=False``, if the improvement
#  |  of the criterion is identical for several splits enumerated during the
#  |  search of the best split. To obtain a deterministic behaviour during
#  |  fitting, ``random_state`` has to be fixed.
#  |
#  |  References
#  |  ----------
#  |  .. [1] L. Breiman, "Random Forests", Machine Learning, 45(1), 5-32, 2001.
#  |
#  |  Examples
#  |  --------
#  |  >>> from sklearn.ensemble import RandomForestClassifier
#  |  >>> from sklearn.datasets import make_classification
#  |  >>> X, y = make_classification(n_samples=1000, n_features=4,
#  |  ...                            n_informative=2, n_redundant=0,
#  |  ...                            random_state=0, shuffle=False)
#  |  >>> clf = RandomForestClassifier(max_depth=2, random_state=0)
#  |  >>> clf.fit(X, y)
#  |  RandomForestClassifier(...)
#  |  >>> print(clf.predict([[0, 0, 0, 0]]))
#  |  [1]
#  |
#  |  Method resolution order:
#  |      RandomForestClassifier
#  |      ForestClassifier
#  |      sklearn.base.ClassifierMixin
#  |      BaseForest
#  |      sklearn.base.MultiOutputMixin
#  |      sklearn.ensemble._base.BaseEnsemble
#  |      sklearn.base.MetaEstimatorMixin
#  |      sklearn.base.BaseEstimator
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, n_estimators=100, *, criterion='gini', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features='auto', max_leaf_nodes=None, min_impurity_decrease=0.0, bootstrap=True, oob_score=False, n_jobs=None, random_state=None, verbose=0, warm_start=False, class_weight=None, ccp_alpha=0.0, max_samples=None)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __abstractmethods__ = frozenset()
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from ForestClassifier:
#  |
#  |  predict(self, X)
#  |      Predict class for X.
#  |
#  |      The predicted class of an input sample is a vote by the trees in
#  |      the forest, weighted by their probability estimates. That is,
#  |      the predicted class is the one with highest mean probability
#  |      estimate across the trees.
#  |
#  |      Parameters
#  |      ----------
#  |      X : {array-like, sparse matrix} of shape (n_samples, n_features)
#  |          The input samples. Internally, its dtype will be converted to
#  |          ``dtype=np.float32``. If a sparse matrix is provided, it will be
#  |          converted into a sparse ``csr_matrix``.
#  |
#  |      Returns
#  |      -------
#  |      y : ndarray of shape (n_samples,) or (n_samples, n_outputs)
#  |          The predicted classes.
#  |
#  |  predict_log_proba(self, X)
#  |      Predict class log-probabilities for X.
#  |
#  |      The predicted class log-probabilities of an input sample is computed as
#  |      the log of the mean predicted class probabilities of the trees in the
#  |      forest.
#  |
#  |      Parameters
#  |      ----------
#  |      X : {array-like, sparse matrix} of shape (n_samples, n_features)
#  |          The input samples. Internally, its dtype will be converted to
#  |          ``dtype=np.float32``. If a sparse matrix is provided, it will be
#  |          converted into a sparse ``csr_matrix``.
#  |
#  |      Returns
#  |      -------
#  |      p : ndarray of shape (n_samples, n_classes), or a list of such arrays
#  |          The class probabilities of the input samples. The order of the
#  |          classes corresponds to that in the attribute :term:`classes_`.
#  |
#  |  predict_proba(self, X)
#  |      Predict class probabilities for X.
#  |
#  |      The predicted class probabilities of an input sample are computed as
#  |      the mean predicted class probabilities of the trees in the forest.
#  |      The class probability of a single tree is the fraction of samples of
#  |      the same class in a leaf.
#  |
#  |      Parameters
#  |      ----------
#  |      X : {array-like, sparse matrix} of shape (n_samples, n_features)
#  |          The input samples. Internally, its dtype will be converted to
#  |          ``dtype=np.float32``. If a sparse matrix is provided, it will be
#  |          converted into a sparse ``csr_matrix``.
#  |
#  |      Returns
#  |      -------
#  |      p : ndarray of shape (n_samples, n_classes), or a list of such arrays
#  |          The class probabilities of the input samples. The order of the
#  |          classes corresponds to that in the attribute :term:`classes_`.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from sklearn.base.ClassifierMixin:
#  |
#  |  score(self, X, y, sample_weight=None)
#  |      Return the mean accuracy on the given test data and labels.
#  |
#  |      In multi-label classification, this is the subset accuracy
#  |      which is a harsh metric since you require for each sample that
#  |      each label set be correctly predicted.
#  |
#  |      Parameters
#  |      ----------
#  |      X : array-like of shape (n_samples, n_features)
#  |          Test samples.
#  |
#  |      y : array-like of shape (n_samples,) or (n_samples, n_outputs)
#  |          True labels for `X`.
#  |
#  |      sample_weight : array-like of shape (n_samples,), default=None
#  |          Sample weights.
#  |
#  |      Returns
#  |      -------
#  |      score : float
#  |          Mean accuracy of ``self.predict(X)`` wrt. `y`.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from sklearn.base.ClassifierMixin:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from BaseForest:
#  |
#  |  apply(self, X)
#  |      Apply trees in the forest to X, return leaf indices.
#  |
#  |      Parameters
#  |      ----------
#  |      X : {array-like, sparse matrix} of shape (n_samples, n_features)
#  |          The input samples. Internally, its dtype will be converted to
#  |          ``dtype=np.float32``. If a sparse matrix is provided, it will be
#  |          converted into a sparse ``csr_matrix``.
#  |
#  |      Returns
#  |      -------
#  |      X_leaves : ndarray of shape (n_samples, n_estimators)
#  |          For each datapoint x in X and for each tree in the forest,
#  |          return the index of the leaf x ends up in.
#  |
#  |  decision_path(self, X)
#  |      Return the decision path in the forest.
#  |
#  |      .. versionadded:: 0.18
#  |
#  |      Parameters
#  |      ----------
#  |      X : {array-like, sparse matrix} of shape (n_samples, n_features)
#  |          The input samples. Internally, its dtype will be converted to
#  |          ``dtype=np.float32``. If a sparse matrix is provided, it will be
#  |          converted into a sparse ``csr_matrix``.
#  |
#  |      Returns
#  |      -------
#  |      indicator : sparse matrix of shape (n_samples, n_nodes)
#  |          Return a node indicator matrix where non zero elements indicates
#  |          that the samples goes through the nodes. The matrix is of CSR
#  |          format.
#  |
#  |      n_nodes_ptr : ndarray of shape (n_estimators + 1,)
#  |          The columns from indicator[n_nodes_ptr[i]:n_nodes_ptr[i+1]]
#  |          gives the indicator value for the i-th estimator.
#  |
#  |  fit(self, X, y, sample_weight=None)
#  |      Build a forest of trees from the training set (X, y).
#  |
#  |      Parameters
#  |      ----------
#  |      X : {array-like, sparse matrix} of shape (n_samples, n_features)
#  |          The training input samples. Internally, its dtype will be converted
#  |          to ``dtype=np.float32``. If a sparse matrix is provided, it will be
#  |          converted into a sparse ``csc_matrix``.
#  |
#  |      y : array-like of shape (n_samples,) or (n_samples, n_outputs)
#  |          The target values (class labels in classification, real numbers in
#  |          regression).
#  |
#  |      sample_weight : array-like of shape (n_samples,), default=None
#  |          Sample weights. If None, then samples are equally weighted. Splits
#  |          that would create child nodes with net zero or negative weight are
#  |          ignored while searching for a split in each node. In the case of
#  |          classification, splits are also ignored if they would result in any
#  |          single class carrying a negative weight in either child node.
#  |
#  |      Returns
#  |      -------
#  |      self : object
#  |          Fitted estimator.
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties inherited from BaseForest:
#  |
#  |  feature_importances_
#  |      The impurity-based feature importances.
#  |
#  |      The higher, the more important the feature.
#  |      The importance of a feature is computed as the (normalized)
#  |      total reduction of the criterion brought by that feature.  It is also
#  |      known as the Gini importance.
#  |
#  |      Warning: impurity-based feature importances can be misleading for
#  |      high cardinality features (many unique values). See
#  |      :func:`sklearn.inspection.permutation_importance` as an alternative.
#  |
#  |      Returns
#  |      -------
#  |      feature_importances_ : ndarray of shape (n_features,)
#  |          The values of this array sum to 1, unless all trees are single node
#  |          trees consisting of only the root node, in which case it will be an
#  |          array of zeros.
#  |
#  |  n_features_
#  |      DEPRECATED: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#  |
#  |      Number of features when fitting the estimator.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from sklearn.ensemble._base.BaseEnsemble:
#  |
#  |  __getitem__(self, index)
#  |      Return the index'th estimator in the ensemble.
#  |
#  |  __iter__(self)
#  |      Return iterator over estimators in the ensemble.
#  |
#  |  __len__(self)
#  |      Return the number of estimators in the ensemble.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from sklearn.ensemble._base.BaseEnsemble:
#  |
#  |  __annotations__ = {'_required_parameters': typing.List[str]}
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from sklearn.base.BaseEstimator:
#  |
#  |  __getstate__(self)
#  |
#  |  __repr__(self, N_CHAR_MAX=700)
#  |      Return repr(self).
#  |
#  |  __setstate__(self, state)
#  |
#  |  get_params(self, deep=True)
#  |      Get parameters for this estimator.
#  |
#  |      Parameters
#  |      ----------
#  |      deep : bool, default=True
#  |          If True, will return the parameters for this estimator and
#  |          contained subobjects that are estimators.
#  |
#  |      Returns
#  |      -------
#  |      params : dict
#  |          Parameter names mapped to their values.
#  |
#  |  set_params(self, **params)
#  |      Set the parameters of this estimator.
#  |
#  |      The method works on simple estimators as well as on nested objects
#  |      (such as :class:`~sklearn.pipeline.Pipeline`). The latter have
#  |      parameters of the form ``<component>__<parameter>`` so that it's
#  |      possible to update each component of a nested object.
#  |
#  |      Parameters
#  |      ----------
#  |      **params : dict
#  |          Estimator parameters.
#  |
#  |      Returns
#  |      -------
#  |      self : estimator instance
#  |          Estimator instance.

# %%
def cog_funs(first_layer_model,train_X):
    ret = []
    for key,v in first_layer_model.items():
        ret.append(v.predict_log_proba(train_X)[:,0])
    ret = np.array(ret)
    return ret.T

# %%
train_X_cog_funs = cog_funs(first_layer_model,train_X)

# %%
train_X = np.array([np.concatenate([a,b],axis=None) for a,b in zip(train_X,train_X_cog_funs)])

# %%
mbti_types = ['ENFJ','ENFP','ENTJ','ENTP','ESFJ','ESFP','ESTJ','ESTP',
    'INFJ','INFP','INTJ','INTP','ISFJ','ISFP','ISTJ','ISTP']
type2int = {t:i for i,t in enumerate(mbti_types)}
int2type = {i:t for i,t in enumerate(mbti_types)}

# %%
train_y = df.mbti_type.apply(lambda x:type2int[x]).values

# %% [markdown]
# ## read in data

# %%
def first_layer_output(Xtrain, ytrain):
    Xprob = []
    
    
    for i,sample in enumerate(Xtrain):
        Xprob.append(first_layer_output_predict(sample))
        
        if i % 1000 == 0:
            print(i,'out of', len(Xtrain), 'has been transformed')
            print(time.time() - start)
        
    df = pd.DataFrame(Xprob)
    
    # renameing columns
    df.rename(columns = dict(zip(df.columns,sorted(models.keys()))),inplace=True)
    
    df['label'] = ytrain
    
    return df

# %% [markdown]
# ## Another thing to do is to transfer the label to int

# %%
# Xtrain = train['body'].values
# ytrain = train['mbti_type'].values
# Xtest = test['body'].values
# ytest = test['mbti_type'].values
# del train
# del test
# with open('mbti_to_number_encoder','wb') as f:
#     pickle.dump(le,f)
# le = preprocessing.LabelEncoder()
# ytrain = le.fit_transform(ytrain)
# ytest = le.transform(ytest)
# train_df = first_layer_output(Xtrain, ytrain)
# test_df  = first_layer_output(Xtest, ytest)
# ytrain = train_df['label'].values
# train_df.drop(['label'], axis=1, inplace=True)
# Xtrain = train_df.values

# ytest = test_df['label'].values
# test_df.drop(['label'], axis=1, inplace=True)
# Xtest = test_df.values
# torch.save(torch.from_numpy(Xtrain.astype('float32')),'../data/Xtrain.pt')
# torch.save(torch.from_numpy(ytrain), 'ytrain.pt')
# torch.save(torch.from_numpy(Xtest.astype('float32')),'../data/Xtest.pt')
# torch.save(torch.from_numpy(ytest), 'ytest.pt')

# %%
# read the label encoder
with open('../data/mbti_to_number_encoder','rb') as f:
    le = pickle.load(f)

# %%
Xtrain = torch.load('../data/Xtrain.pt')
ytrain = torch.load('../data/ytrain.pt')
Xtest = torch.load('../data/Xtest.pt')
ytest = torch.load('../data/ytest.pt')

# %%
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../data/development.csv', index_col=0)
X = df['body']
y = df['type']
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.1,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier(criterion='gini',max_depth=500)

# %%
for i in range(100):
    clf.fit(Xtrain.numpy(), ytrain.numpy())
    print(i, accuracy_score(ytest.numpy(), clf.predict(Xtest.numpy())))
# Out:
# 0 0.269375
# 1 0.278375
# 2 0.271125
# 3 0.276125
# 4 0.270375
# 5 0.27175
# 6 0.27375
# 7 0.2745
# 8 0.26925
# 9 0.276375
# 10 0.276125
# 11 0.274875
# 12 0.2775
# 13 0.273375
# 14 0.271125
# 15 0.269875
# 16 0.27075
# 17 0.27225
# 18 0.27575
# 19 0.273
# 20 0.27525
# 21 0.27425
# 22 0.270375
# 23 0.27375
# 24 0.270875
# 25 0.27325
# 26 0.279125
# 27 0.273625
# 28 0.2745
# 29 0.279
# 30 0.271
# 31 0.269
# 32 0.273875
# 33 0.2735
# 34 0.2685
# 35 0.2785
# 36 0.274125
# 37 0.269125
# 38 0.276
# 39 0.27475
# 40 0.272125
# 41 0.275125
# 42 0.2715
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1088/2752459416.py in <module>
#       1 for i in range(100):
# ----> 2     clf.fit(Xtrain.numpy(), ytrain.numpy())
#       3     print(i, accuracy_score(ytest.numpy(), clf.predict(Xtest.numpy())))
#
# ~/anaconda3/envs/tc113/lib/python3.9/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     935         """
#     936
# --> 937         super().fit(
#     938             X,
#     939             y,
#
# ~/anaconda3/envs/tc113/lib/python3.9/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     418             )
#     419
# --> 420         builder.build(self.tree_, X, y, sample_weight)
#     421
#     422         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %%
train_dl = DataLoader(train_data,shuffle=True, batch_size=500)
test_dl = DataLoader(test_data,shuffle=True,batch_size=500)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

class NeuralN(nn.Module):
    def __init__(self) -> None:
        super().__init__()
        
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(32, 32),
            nn.ReLU(),
            nn.Linear(32,32),
            nn.MaxPool1d(5, stride=1),
            nn.SiLU(),
            nn.Linear(32-5+1,20),
            nn.ReLU(),
            nn.Linear(20,16)
        )
    
    def forward(self,x):
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralN().to(device)

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-1)

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    for batch, (X,y) in enumerate(dataloader):
        X,y = X.to(device), y.to(device)
        
        pred = model(X)
        loss = loss_fn(pred, y)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # if batch % 100 == 0:
        #     loss, current = loss.item(), batch * len(X)
        #     print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

# %%
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
epochs = 20
for t in range(200):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dl, model, loss_fn, optimizer)
    test(test_dl, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 16.3%, Avg loss: 2.619456
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 22.1%, Avg loss: 2.228087
#
# Epoch 3
# -------------------------------
# Test Error:
#  Accuracy: 21.5%, Avg loss: 2.121699
#
# Epoch 4
# -------------------------------
# Test Error:
#  Accuracy: 20.8%, Avg loss: 2.109974
#
# Epoch 5
# -------------------------------
# Test Error:
#  Accuracy: 22.4%, Avg loss: 2.103401
#
# Epoch 6
# -------------------------------
# Test Error:
#  Accuracy: 22.0%, Avg loss: 2.099401
#
# Epoch 7
# -------------------------------
# Test Error:
#  Accuracy: 22.4%, Avg loss: 2.096186
#
# Epoch 8
# -------------------------------
# Test Error:
#  Accuracy: 22.4%, Avg loss: 2.093070
#
# Epoch 9
# -------------------------------
# Test Error:
#  Accuracy: 22.4%, Avg loss: 2.090246
#
# Epoch 10
# -------------------------------
# Test Error:
#  Accuracy: 23.2%, Avg loss: 2.088287
#
# Epoch 11
# -------------------------------
# Test Error:
#  Accuracy: 22.9%, Avg loss: 2.084865
#
# Epoch 12
# -------------------------------
# Test Error:
#  Accuracy: 22.5%, Avg loss: 2.082384
#
# Epoch 13
# -------------------------------
# Test Error:
#  Accuracy: 22.4%, Avg loss: 2.078962
#
# Epoch 14
# -------------------------------
# Test Error:
#  Accuracy: 22.1%, Avg loss: 2.076668
#
# Epoch 15
# -------------------------------
# Test Error:
#  Accuracy: 26.9%, Avg loss: 2.073626
#
# Epoch 16
# -------------------------------
# Test Error:
#  Accuracy: 23.2%, Avg loss: 2.070241
#
# Epoch 17
# -------------------------------
# Test Error:
#  Accuracy: 25.6%, Avg loss: 2.067811
#
# Epoch 18
# -------------------------------
# Test Error:
#  Accuracy: 23.9%, Avg loss: 2.064604
#
# Epoch 19
# -------------------------------
# Test Error:
#  Accuracy: 26.3%, Avg loss: 2.061548
#
# Epoch 20
# -------------------------------
# Test Error:
#  Accuracy: 27.4%, Avg loss: 2.058735
#
# Epoch 21
# -------------------------------
# Test Error:
#  Accuracy: 25.6%, Avg loss: 2.055262
#
# Epoch 22
# -------------------------------
# Test Error:
#  Accuracy: 25.5%, Avg loss: 2.051656
#
# Epoch 23
# -------------------------------
# Test Error:
#  Accuracy: 26.1%, Avg loss: 2.047167
#
# Epoch 24
# -------------------------------
# Test Error:
#  Accuracy: 27.8%, Avg loss: 2.042385
#
# Epoch 25
# -------------------------------
# Test Error:
#  Accuracy: 28.0%, Avg loss: 2.035060
#
# Epoch 26
# -------------------------------
# Test Error:
#  Accuracy: 28.2%, Avg loss: 2.026323
#
# Epoch 27
# -------------------------------
# Test Error:
#  Accuracy: 28.5%, Avg loss: 2.014085
#
# Epoch 28
# -------------------------------
# Test Error:
#  Accuracy: 30.3%, Avg loss: 2.000103
#
# Epoch 29
# -------------------------------
# Test Error:
#  Accuracy: 30.8%, Avg loss: 1.986369
#
# Epoch 30
# -------------------------------
# Test Error:
#  Accuracy: 31.5%, Avg loss: 1.975495
#
# Epoch 31
# -------------------------------
# Test Error:
#  Accuracy: 32.0%, Avg loss: 1.968141
#
# Epoch 32
# -------------------------------
# Test Error:
#  Accuracy: 32.3%, Avg loss: 1.963073
#
# Epoch 33
# -------------------------------
# Test Error:
#  Accuracy: 32.3%, Avg loss: 1.957882
#
# Epoch 34
# -------------------------------
# Test Error:
#  Accuracy: 32.9%, Avg loss: 1.954162
#
# Epoch 35
# -------------------------------
# Test Error:
#  Accuracy: 32.8%, Avg loss: 1.951407
#
# Epoch 36
# -------------------------------
# Test Error:
#  Accuracy: 33.0%, Avg loss: 1.948714
#
# Epoch 37
# -------------------------------
# Test Error:
#  Accuracy: 33.0%, Avg loss: 1.946761
#
# Epoch 38
# -------------------------------
# Test Error:
#  Accuracy: 33.4%, Avg loss: 1.944087
#
# Epoch 39
# -------------------------------
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.942326
#
# Epoch 40
# -------------------------------
# Test Error:
#  Accuracy: 33.5%, Avg loss: 1.939711
#
# Epoch 41
# -------------------------------
# Test Error:
#  Accuracy: 33.6%, Avg loss: 1.937732
#
# Epoch 42
# -------------------------------
# Test Error:
#  Accuracy: 33.8%, Avg loss: 1.936021
#
# Epoch 43
# -------------------------------
# Test Error:
#  Accuracy: 33.8%, Avg loss: 1.934763
#
# Epoch 44
# -------------------------------
# Test Error:
#  Accuracy: 33.9%, Avg loss: 1.932531
#
# Epoch 45
# -------------------------------
# Test Error:
#  Accuracy: 33.9%, Avg loss: 1.930438
#
# Epoch 46
# -------------------------------
# Test Error:
#  Accuracy: 34.1%, Avg loss: 1.928164
#
# Epoch 47
# -------------------------------
# Test Error:
#  Accuracy: 34.1%, Avg loss: 1.926233
#
# Epoch 48
# -------------------------------
# Test Error:
#  Accuracy: 34.2%, Avg loss: 1.923984
#
# Epoch 49
# -------------------------------
# Test Error:
#  Accuracy: 34.2%, Avg loss: 1.921843
#
# Epoch 50
# -------------------------------
# Test Error:
#  Accuracy: 34.3%, Avg loss: 1.919742
#
# Epoch 51
# -------------------------------
# Test Error:
#  Accuracy: 34.3%, Avg loss: 1.917270
#
# Epoch 52
# -------------------------------
# Test Error:
#  Accuracy: 34.4%, Avg loss: 1.914723
#
# Epoch 53
# -------------------------------
# Test Error:
#  Accuracy: 34.5%, Avg loss: 1.912254
#
# Epoch 54
# -------------------------------
# Test Error:
#  Accuracy: 34.8%, Avg loss: 1.909660
#
# Epoch 55
# -------------------------------
# Test Error:
#  Accuracy: 34.7%, Avg loss: 1.907673
#
# Epoch 56
# -------------------------------
# Test Error:
#  Accuracy: 35.0%, Avg loss: 1.905005
#
# Epoch 57
# -------------------------------
# Test Error:
#  Accuracy: 35.0%, Avg loss: 1.903860
#
# Epoch 58
# -------------------------------
# Test Error:
#  Accuracy: 35.0%, Avg loss: 1.900822
#
# Epoch 59
# -------------------------------
# Test Error:
#  Accuracy: 35.2%, Avg loss: 1.898158
#
# Epoch 60
# -------------------------------
# Test Error:
#  Accuracy: 35.2%, Avg loss: 1.897151
#
# Epoch 61
# -------------------------------
# Test Error:
#  Accuracy: 35.4%, Avg loss: 1.894923
#
# Epoch 62
# -------------------------------
# Test Error:
#  Accuracy: 35.3%, Avg loss: 1.893399
#
# Epoch 63
# -------------------------------
# Test Error:
#  Accuracy: 35.7%, Avg loss: 1.891490
#
# Epoch 64
# -------------------------------
# Test Error:
#  Accuracy: 35.5%, Avg loss: 1.889907
#
# Epoch 65
# -------------------------------
# Test Error:
#  Accuracy: 35.7%, Avg loss: 1.888464
#
# Epoch 66
# -------------------------------
# Test Error:
#  Accuracy: 35.9%, Avg loss: 1.887162
#
# Epoch 67
# -------------------------------
# Test Error:
#  Accuracy: 35.6%, Avg loss: 1.886884
#
# Epoch 68
# -------------------------------
# Test Error:
#  Accuracy: 35.8%, Avg loss: 1.885033
#
# Epoch 69
# -------------------------------
# Test Error:
#  Accuracy: 35.8%, Avg loss: 1.884402
#
# Epoch 70
# -------------------------------
# Test Error:
#  Accuracy: 36.0%, Avg loss: 1.883019
#
# Epoch 71
# -------------------------------
# Test Error:
#  Accuracy: 36.2%, Avg loss: 1.881965
#
# Epoch 72
# -------------------------------
# Test Error:
#  Accuracy: 35.8%, Avg loss: 1.881633
#
# Epoch 73
# -------------------------------
# Test Error:
#  Accuracy: 35.8%, Avg loss: 1.880662
#
# Epoch 74
# -------------------------------
# Test Error:
#  Accuracy: 36.0%, Avg loss: 1.879492
#
# Epoch 75
# -------------------------------
# Test Error:
#  Accuracy: 36.0%, Avg loss: 1.878371
#
# Epoch 76
# -------------------------------
# Test Error:
#  Accuracy: 36.0%, Avg loss: 1.877716
#
# Epoch 77
# -------------------------------
# Test Error:
#  Accuracy: 36.1%, Avg loss: 1.877550
#
# Epoch 78
# -------------------------------
# Test Error:
#  Accuracy: 36.0%, Avg loss: 1.876594
#
# Epoch 79
# -------------------------------
# Test Error:
#  Accuracy: 36.1%, Avg loss: 1.875943
#
# Epoch 80
# -------------------------------
# Test Error:
#  Accuracy: 35.8%, Avg loss: 1.875545
#
# Epoch 81
# -------------------------------
# Test Error:
#  Accuracy: 35.7%, Avg loss: 1.874790
#
# Epoch 82
# -------------------------------
# Test Error:
#  Accuracy: 35.9%, Avg loss: 1.873541
#
# Epoch 83
# -------------------------------
# Test Error:
#  Accuracy: 36.0%, Avg loss: 1.872991
#
# Epoch 84
# -------------------------------
# Test Error:
#  Accuracy: 35.8%, Avg loss: 1.872695
#
# Epoch 85
# -------------------------------
# Test Error:
#  Accuracy: 35.8%, Avg loss: 1.871571
#
# Epoch 86
# -------------------------------
# Test Error:
#  Accuracy: 35.8%, Avg loss: 1.870096
#
# Epoch 87
# -------------------------------
# Test Error:
#  Accuracy: 35.9%, Avg loss: 1.869126
#
# Epoch 88
# -------------------------------
# Test Error:
#  Accuracy: 35.8%, Avg loss: 1.868552
#
# Epoch 89
# -------------------------------
# Test Error:
#  Accuracy: 36.0%, Avg loss: 1.867427
#
# Epoch 90
# -------------------------------
# Test Error:
#  Accuracy: 35.8%, Avg loss: 1.866353
#
# Epoch 91
# -------------------------------
# Test Error:
#  Accuracy: 36.1%, Avg loss: 1.865063
#
# Epoch 92
# -------------------------------
# Test Error:
#  Accuracy: 36.0%, Avg loss: 1.863721
#
# Epoch 93
# -------------------------------
# Test Error:
#  Accuracy: 36.0%, Avg loss: 1.863145
#
# Epoch 94
# -------------------------------
# Test Error:
#  Accuracy: 36.4%, Avg loss: 1.861357
#
# Epoch 95
# -------------------------------
# Test Error:
#  Accuracy: 36.2%, Avg loss: 1.859248
#
# Epoch 96
# -------------------------------
# Test Error:
#  Accuracy: 36.3%, Avg loss: 1.857311
#
# Epoch 97
# -------------------------------
# Test Error:
#  Accuracy: 36.1%, Avg loss: 1.857173
#
# Epoch 98
# -------------------------------
# Test Error:
#  Accuracy: 36.5%, Avg loss: 1.853519
#
# Epoch 99
# -------------------------------
# Test Error:
#  Accuracy: 36.4%, Avg loss: 1.852355
#
# Epoch 100
# -------------------------------
# Test Error:
#  Accuracy: 36.9%, Avg loss: 1.849534
#
# Epoch 101
# -------------------------------
# Test Error:
#  Accuracy: 37.1%, Avg loss: 1.849088
#
# Epoch 102
# -------------------------------
# Test Error:
#  Accuracy: 37.4%, Avg loss: 1.845531
#
# Epoch 103
# -------------------------------
# Test Error:
#  Accuracy: 37.7%, Avg loss: 1.843896
#
# Epoch 104
# -------------------------------
# Test Error:
#  Accuracy: 38.1%, Avg loss: 1.841522
#
# Epoch 105
# -------------------------------
# Test Error:
#  Accuracy: 37.8%, Avg loss: 1.840257
#
# Epoch 106
# -------------------------------
# Test Error:
#  Accuracy: 38.0%, Avg loss: 1.838528
#
# Epoch 107
# -------------------------------
# Test Error:
#  Accuracy: 38.5%, Avg loss: 1.835558
#
# Epoch 108
# -------------------------------
# Test Error:
#  Accuracy: 38.3%, Avg loss: 1.834360
#
# Epoch 109
# -------------------------------
# Test Error:
#  Accuracy: 38.6%, Avg loss: 1.831908
#
# Epoch 110
# -------------------------------
# Test Error:
#  Accuracy: 38.6%, Avg loss: 1.831768
#
# Epoch 111
# -------------------------------
# Test Error:
#  Accuracy: 38.6%, Avg loss: 1.830060
#
# Epoch 112
# -------------------------------
# Test Error:
#  Accuracy: 38.4%, Avg loss: 1.829233
#
# Epoch 113
# -------------------------------
# Test Error:
#  Accuracy: 38.6%, Avg loss: 1.827826
#
# Epoch 114
# -------------------------------
# Test Error:
#  Accuracy: 38.7%, Avg loss: 1.826902
#
# Epoch 115
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.826431
#
# Epoch 116
# -------------------------------
# Test Error:
#  Accuracy: 38.7%, Avg loss: 1.826964
#
# Epoch 117
# -------------------------------
# Test Error:
#  Accuracy: 38.8%, Avg loss: 1.824954
#
# Epoch 118
# -------------------------------
# Test Error:
#  Accuracy: 38.6%, Avg loss: 1.825754
#
# Epoch 119
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.823385
#
# Epoch 120
# -------------------------------
# Test Error:
#  Accuracy: 38.8%, Avg loss: 1.823603
#
# Epoch 121
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.822770
#
# Epoch 122
# -------------------------------
# Test Error:
#  Accuracy: 38.8%, Avg loss: 1.822934
#
# Epoch 123
# -------------------------------
# Test Error:
#  Accuracy: 38.7%, Avg loss: 1.823502
#
# Epoch 124
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.822804
#
# Epoch 125
# -------------------------------
# Test Error:
#  Accuracy: 38.8%, Avg loss: 1.822789
#
# Epoch 126
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.821889
#
# Epoch 127
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.822068
#
# Epoch 128
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.821239
#
# Epoch 129
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.820988
#
# Epoch 130
# -------------------------------
# Test Error:
#  Accuracy: 39.1%, Avg loss: 1.820493
#
# Epoch 131
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.820294
#
# Epoch 132
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.821073
#
# Epoch 133
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.819686
#
# Epoch 134
# -------------------------------
# Test Error:
#  Accuracy: 38.8%, Avg loss: 1.821786
#
# Epoch 135
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.820472
#
# Epoch 136
# -------------------------------
# Test Error:
#  Accuracy: 38.8%, Avg loss: 1.819644
#
# Epoch 137
# -------------------------------
# Test Error:
#  Accuracy: 38.7%, Avg loss: 1.820801
#
# Epoch 138
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.819822
#
# Epoch 139
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.820143
#
# Epoch 140
# -------------------------------
# Test Error:
#  Accuracy: 38.8%, Avg loss: 1.820104
#
# Epoch 141
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.819592
#
# Epoch 142
# -------------------------------
# Test Error:
#  Accuracy: 38.7%, Avg loss: 1.819677
#
# Epoch 143
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.818705
#
# Epoch 144
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.819106
#
# Epoch 145
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.818347
#
# Epoch 146
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.819065
#
# Epoch 147
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.819347
#
# Epoch 148
# -------------------------------
# Test Error:
#  Accuracy: 38.8%, Avg loss: 1.818996
#
# Epoch 149
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.819077
#
# Epoch 150
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.818098
#
# Epoch 151
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.817911
#
# Epoch 152
# -------------------------------
# Test Error:
#  Accuracy: 38.8%, Avg loss: 1.819153
#
# Epoch 153
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.818981
#
# Epoch 154
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.819568
#
# Epoch 155
# -------------------------------
# Test Error:
#  Accuracy: 38.6%, Avg loss: 1.818601
#
# Epoch 156
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.817512
#
# Epoch 157
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.817321
#
# Epoch 158
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.817426
#
# Epoch 159
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.817176
#
# Epoch 160
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.817499
#
# Epoch 161
# -------------------------------
# Test Error:
#  Accuracy: 39.1%, Avg loss: 1.817142
#
# Epoch 162
# -------------------------------
# Test Error:
#  Accuracy: 38.8%, Avg loss: 1.817501
#
# Epoch 163
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.817342
#
# Epoch 164
# -------------------------------
# Test Error:
#  Accuracy: 38.8%, Avg loss: 1.817082
#
# Epoch 165
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.816484
#
# Epoch 166
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.817138
#
# Epoch 167
# -------------------------------
# Test Error:
#  Accuracy: 38.7%, Avg loss: 1.816938
#
# Epoch 168
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.816342
#
# Epoch 169
# -------------------------------
# Test Error:
#  Accuracy: 38.8%, Avg loss: 1.817986
#
# Epoch 170
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.816861
#
# Epoch 171
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.816320
#
# Epoch 172
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.816493
#
# Epoch 173
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.815935
#
# Epoch 174
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.815923
#
# Epoch 175
# -------------------------------
# Test Error:
#  Accuracy: 38.7%, Avg loss: 1.815975
#
# Epoch 176
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.816186
#
# Epoch 177
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.815886
#
# Epoch 178
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.815395
#
# Epoch 179
# -------------------------------
# Test Error:
#  Accuracy: 38.8%, Avg loss: 1.815436
#
# Epoch 180
# -------------------------------
# Test Error:
#  Accuracy: 38.6%, Avg loss: 1.815887
#
# Epoch 181
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.815651
#
# Epoch 182
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.815235
#
# Epoch 183
# -------------------------------
# Test Error:
#  Accuracy: 38.7%, Avg loss: 1.816181
#
# Epoch 184
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.814529
#
# Epoch 185
# -------------------------------
# Test Error:
#  Accuracy: 38.8%, Avg loss: 1.816563
#
# Epoch 186
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.814850
#
# Epoch 187
# -------------------------------
# Test Error:
#  Accuracy: 39.1%, Avg loss: 1.815090
#
# Epoch 188
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.815007
#
# Epoch 189
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.814641
#
# Epoch 190
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.815271
#
# Epoch 191
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.814300
#
# Epoch 192
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.815100
#
# Epoch 193
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.814209
#
# Epoch 194
# -------------------------------
# Test Error:
#  Accuracy: 38.8%, Avg loss: 1.814194
#
# Epoch 195
# -------------------------------
# Test Error:
#  Accuracy: 38.8%, Avg loss: 1.814110
#
# Epoch 196
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.813350
#
# Epoch 197
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.814168
#
# Epoch 198
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.813147
#
# Epoch 199
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.813123
#
# Epoch 200
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.813220
#
# Done!

# %%
for t in range(100):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dl, model, loss_fn, optimizer)
    test(test_dl, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.814872
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 38.6%, Avg loss: 1.814110
#
# Epoch 3
# -------------------------------
# Test Error:
#  Accuracy: 38.6%, Avg loss: 1.812954
#
# Epoch 4
# -------------------------------
# Test Error:
#  Accuracy: 38.8%, Avg loss: 1.813648
#
# Epoch 5
# -------------------------------
# Test Error:
#  Accuracy: 38.8%, Avg loss: 1.812658
#
# Epoch 6
# -------------------------------
# Test Error:
#  Accuracy: 38.6%, Avg loss: 1.814167
#
# Epoch 7
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.812439
#
# Epoch 8
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.812962
#
# Epoch 9
# -------------------------------
# Test Error:
#  Accuracy: 38.8%, Avg loss: 1.812491
#
# Epoch 10
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.811833
#
# Epoch 11
# -------------------------------
# Test Error:
#  Accuracy: 38.8%, Avg loss: 1.812112
#
# Epoch 12
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.811207
#
# Epoch 13
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.812029
#
# Epoch 14
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.811748
#
# Epoch 15
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.811030
#
# Epoch 16
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.811036
#
# Epoch 17
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.812370
#
# Epoch 18
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.813626
#
# Epoch 19
# -------------------------------
# Test Error:
#  Accuracy: 38.8%, Avg loss: 1.811551
#
# Epoch 20
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.810917
#
# Epoch 21
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.811073
#
# Epoch 22
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.809594
#
# Epoch 23
# -------------------------------
# Test Error:
#  Accuracy: 38.8%, Avg loss: 1.809948
#
# Epoch 24
# -------------------------------
# Test Error:
#  Accuracy: 39.1%, Avg loss: 1.809100
#
# Epoch 25
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.809144
#
# Epoch 26
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.809432
#
# Epoch 27
# -------------------------------
# Test Error:
#  Accuracy: 39.1%, Avg loss: 1.809071
#
# Epoch 28
# -------------------------------
# Test Error:
#  Accuracy: 38.9%, Avg loss: 1.808504
#
# Epoch 29
# -------------------------------
# Test Error:
#  Accuracy: 39.1%, Avg loss: 1.808610
#
# Epoch 30
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.809500
#
# Epoch 31
# -------------------------------
# Test Error:
#  Accuracy: 39.3%, Avg loss: 1.808651
#
# Epoch 32
# -------------------------------
# Test Error:
#  Accuracy: 39.0%, Avg loss: 1.807939
#
# Epoch 33
# -------------------------------
# Test Error:
#  Accuracy: 39.1%, Avg loss: 1.807589
#
# Epoch 34
# -------------------------------
# Test Error:
#  Accuracy: 39.3%, Avg loss: 1.806828
#
# Epoch 35
# -------------------------------
# Test Error:
#  Accuracy: 39.2%, Avg loss: 1.806665
#
# Epoch 36
# -------------------------------
# Test Error:
#  Accuracy: 39.1%, Avg loss: 1.806689
#
# Epoch 37
# -------------------------------
# Test Error:
#  Accuracy: 39.3%, Avg loss: 1.806298
#
# Epoch 38
# -------------------------------
# Test Error:
#  Accuracy: 39.1%, Avg loss: 1.806527
#
# Epoch 39
# -------------------------------
# Test Error:
#  Accuracy: 39.1%, Avg loss: 1.806257
#
# Epoch 40
# -------------------------------
# Test Error:
#  Accuracy: 39.2%, Avg loss: 1.806311
#
# Epoch 41
# -------------------------------
# Test Error:
#  Accuracy: 39.1%, Avg loss: 1.805347
#
# Epoch 42
# -------------------------------
# Test Error:
#  Accuracy: 39.3%, Avg loss: 1.805048
#
# Epoch 43
# -------------------------------
# Test Error:
#  Accuracy: 39.3%, Avg loss: 1.804603
#
# Epoch 44
# -------------------------------
# Test Error:
#  Accuracy: 39.3%, Avg loss: 1.804504
#
# Epoch 45
# -------------------------------
# Test Error:
#  Accuracy: 39.2%, Avg loss: 1.804917
#
# Epoch 46
# -------------------------------
# Test Error:
#  Accuracy: 39.5%, Avg loss: 1.803266
#
# Epoch 47
# -------------------------------
# Test Error:
#  Accuracy: 39.7%, Avg loss: 1.803131
#
# Epoch 48
# -------------------------------
# Test Error:
#  Accuracy: 39.3%, Avg loss: 1.802964
#
# Epoch 49
# -------------------------------
# Test Error:
#  Accuracy: 39.5%, Avg loss: 1.802481
#
# Epoch 50
# -------------------------------
# Test Error:
#  Accuracy: 39.6%, Avg loss: 1.801706
#
# Epoch 51
# -------------------------------
# Test Error:
#  Accuracy: 39.4%, Avg loss: 1.801933
#
# Epoch 52
# -------------------------------
# Test Error:
#  Accuracy: 39.3%, Avg loss: 1.801680
#
# Epoch 53
# -------------------------------
# Test Error:
#  Accuracy: 39.3%, Avg loss: 1.801509
#
# Epoch 54
# -------------------------------
# Test Error:
#  Accuracy: 39.4%, Avg loss: 1.801579
#
# Epoch 55
# -------------------------------
# Test Error:
#  Accuracy: 39.5%, Avg loss: 1.800683
#
# Epoch 56
# -------------------------------
# Test Error:
#  Accuracy: 39.4%, Avg loss: 1.800539
#
# Epoch 57
# -------------------------------
# Test Error:
#  Accuracy: 39.6%, Avg loss: 1.800390
#
# Epoch 58
# -------------------------------
# Test Error:
#  Accuracy: 39.5%, Avg loss: 1.800494
#
# Epoch 59
# -------------------------------
# Test Error:
#  Accuracy: 39.6%, Avg loss: 1.799575
#
# Epoch 60
# -------------------------------
# Test Error:
#  Accuracy: 39.6%, Avg loss: 1.798788
#
# Epoch 61
# -------------------------------
# Test Error:
#  Accuracy: 39.5%, Avg loss: 1.799208
#
# Epoch 62
# -------------------------------
# Test Error:
#  Accuracy: 39.6%, Avg loss: 1.798766
#
# Epoch 63
# -------------------------------
# Test Error:
#  Accuracy: 39.6%, Avg loss: 1.798890
#
# Epoch 64
# -------------------------------
# Test Error:
#  Accuracy: 39.4%, Avg loss: 1.799134
#
# Epoch 65
# -------------------------------
# Test Error:
#  Accuracy: 39.5%, Avg loss: 1.798434
#
# Epoch 66
# -------------------------------
# Test Error:
#  Accuracy: 39.4%, Avg loss: 1.797873
#
# Epoch 67
# -------------------------------
# Test Error:
#  Accuracy: 39.6%, Avg loss: 1.797899
#
# Epoch 68
# -------------------------------
# Test Error:
#  Accuracy: 39.5%, Avg loss: 1.797965
#
# Epoch 69
# -------------------------------
# Test Error:
#  Accuracy: 39.4%, Avg loss: 1.797085
#
# Epoch 70
# -------------------------------
# Test Error:
#  Accuracy: 39.7%, Avg loss: 1.795939
#
# Epoch 71
# -------------------------------
# Test Error:
#  Accuracy: 39.7%, Avg loss: 1.796414
#
# Epoch 72
# -------------------------------
# Test Error:
#  Accuracy: 39.7%, Avg loss: 1.795501
#
# Epoch 73
# -------------------------------
# Test Error:
#  Accuracy: 39.6%, Avg loss: 1.797126
#
# Epoch 74
# -------------------------------
# Test Error:
#  Accuracy: 39.4%, Avg loss: 1.796799
#
# Epoch 75
# -------------------------------
# Test Error:
#  Accuracy: 39.8%, Avg loss: 1.796047
#
# Epoch 76
# -------------------------------
# Test Error:
#  Accuracy: 39.5%, Avg loss: 1.795221
#
# Epoch 77
# -------------------------------
# Test Error:
#  Accuracy: 39.5%, Avg loss: 1.795344
#
# Epoch 78
# -------------------------------
# Test Error:
#  Accuracy: 39.5%, Avg loss: 1.794743
#
# Epoch 79
# -------------------------------
# Test Error:
#  Accuracy: 39.5%, Avg loss: 1.795026
#
# Epoch 80
# -------------------------------
# Test Error:
#  Accuracy: 39.6%, Avg loss: 1.794063
#
# Epoch 81
# -------------------------------
# Test Error:
#  Accuracy: 39.3%, Avg loss: 1.794665
#
# Epoch 82
# -------------------------------
# Test Error:
#  Accuracy: 39.6%, Avg loss: 1.793686
#
# Epoch 83
# -------------------------------
# Test Error:
#  Accuracy: 39.7%, Avg loss: 1.794285
#
# Epoch 84
# -------------------------------
# Test Error:
#  Accuracy: 39.6%, Avg loss: 1.792922
#
# Epoch 85
# -------------------------------
# Test Error:
#  Accuracy: 39.5%, Avg loss: 1.793303
#
# Epoch 86
# -------------------------------
# Test Error:
#  Accuracy: 39.5%, Avg loss: 1.793935
#
# Epoch 87
# -------------------------------
# Test Error:
#  Accuracy: 39.7%, Avg loss: 1.792621
#
# Epoch 88
# -------------------------------
# Test Error:
#  Accuracy: 39.5%, Avg loss: 1.792647
#
# Epoch 89
# -------------------------------
# Test Error:
#  Accuracy: 39.5%, Avg loss: 1.792755
#
# Epoch 90
# -------------------------------
# Test Error:
#  Accuracy: 39.7%, Avg loss: 1.792835
#
# Epoch 91
# -------------------------------
# Test Error:
#  Accuracy: 39.3%, Avg loss: 1.793029
#
# Epoch 92
# -------------------------------
# Test Error:
#  Accuracy: 39.5%, Avg loss: 1.792721
#
# Epoch 93
# -------------------------------
# Test Error:
#  Accuracy: 39.8%, Avg loss: 1.791960
#
# Epoch 94
# -------------------------------
# Test Error:
#  Accuracy: 39.7%, Avg loss: 1.793554
#
# Epoch 95
# -------------------------------
# Test Error:
#  Accuracy: 39.4%, Avg loss: 1.792266
#
# Epoch 96
# -------------------------------
# Test Error:
#  Accuracy: 39.4%, Avg loss: 1.792651
#
# Epoch 97
# -------------------------------
# Test Error:
#  Accuracy: 39.5%, Avg loss: 1.791539
#
# Epoch 98
# -------------------------------
# Test Error:
#  Accuracy: 39.5%, Avg loss: 1.791725
#
# Epoch 99
# -------------------------------
# Test Error:
#  Accuracy: 39.8%, Avg loss: 1.791640
#
# Epoch 100
# -------------------------------
# Test Error:
#  Accuracy: 39.4%, Avg loss: 1.790994
#
# Done!
